# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/heart_disease_cleaned_new.csv')
# Out:
# Mounted at /content/drive

# %%
x = df.drop("target", axis=1).values
y = df["target"].values

# %%
scaler = RobustScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.001), input_shape=(x_train.shape[1],)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(256, kernel_regularizer=l2(0.001)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(128, kernel_regularizer=l2(0.001)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, kernel_regularizer=l2(0.001)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, kernel_regularizer=l2(0.001)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(16, kernel_regularizer=l2(0.001)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(patience=15, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(factor=0.5, patience=5, verbose=1)

# %%
history = model.fit(x_train, y_train, epochs=52, batch_size=32,validation_split=0.2,callbacks=[early_stop, reduce_lr],verbose=1)
# Out:
# Epoch 1/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.5482 - loss: 1.5649 - val_accuracy: 0.8243 - val_loss: 1.3099 - learning_rate: 0.0010
# Epoch 2/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6822 - loss: 1.3407 - val_accuracy: 0.8311 - val_loss: 1.2632 - learning_rate: 0.0010
# Epoch 3/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7332 - loss: 1.2710 - val_accuracy: 0.8176 - val_loss: 1.2317 - learning_rate: 0.0010
# Epoch 4/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7541 - loss: 1.2192 - val_accuracy: 0.8243 - val_loss: 1.2133 - learning_rate: 0.0010
# Epoch 5/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7352 - loss: 1.2122 - val_accuracy: 0.8041 - val_loss: 1.1938 - learning_rate: 0.0010
# Epoch 6/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8008 - loss: 1.1606 - val_accuracy: 0.8243 - val_loss: 1.1799 - learning_rate: 0.0010
# Epoch 7/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7938 - loss: 1.1444 - val_accuracy: 0.8311 - val_loss: 1.1672 - learning_rate: 0.0010
# Epoch 8/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8009 - loss: 1.1319 - val_accuracy: 0.8446 - val_loss: 1.1473 - learning_rate: 0.0010
# Epoch 9/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7699 - loss: 1.1617 - val_accuracy: 0.8378 - val_loss: 1.1326 - learning_rate: 0.0010
# Epoch 10/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8134 - loss: 1.0856 - val_accuracy: 0.8243 - val_loss: 1.1239 - learning_rate: 0.0010
# Epoch 11/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7956 - loss: 1.1103 - val_accuracy: 0.8176 - val_loss: 1.1081 - learning_rate: 0.0010
# Epoch 12/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8043 - loss: 1.1045 - val_accuracy: 0.8581 - val_loss: 1.0900 - learning_rate: 0.0010
# Epoch 13/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8168 - loss: 1.0644 - val_accuracy: 0.8581 - val_loss: 1.0798 - learning_rate: 0.0010
# Epoch 14/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8364 - loss: 1.0967 - val_accuracy: 0.8514 - val_loss: 1.0672 - learning_rate: 0.0010
# Epoch 15/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8411 - loss: 1.0296 - val_accuracy: 0.8649 - val_loss: 1.0593 - learning_rate: 0.0010
# Epoch 16/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8170 - loss: 1.0577 - val_accuracy: 0.8581 - val_loss: 1.0483 - learning_rate: 0.0010
# Epoch 17/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8223 - loss: 1.0365 - val_accuracy: 0.8446 - val_loss: 1.0379 - learning_rate: 0.0010
# Epoch 18/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8287 - loss: 1.0294 - val_accuracy: 0.8514 - val_loss: 1.0261 - learning_rate: 0.0010
# Epoch 19/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7983 - loss: 1.0446 - val_accuracy: 0.8514 - val_loss: 1.0200 - learning_rate: 0.0010
# Epoch 20/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8225 - loss: 1.0483 - val_accuracy: 0.8378 - val_loss: 1.0242 - learning_rate: 0.0010
# Epoch 21/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8423 - loss: 0.9827 - val_accuracy: 0.8243 - val_loss: 1.0145 - learning_rate: 0.0010
# Epoch 22/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8219 - loss: 1.0216 - val_accuracy: 0.8378 - val_loss: 1.0087 - learning_rate: 0.0010
# Epoch 23/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8224 - loss: 1.0264 - val_accuracy: 0.8311 - val_loss: 1.0077 - learning_rate: 0.0010
# Epoch 24/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8130 - loss: 1.0136 - val_accuracy: 0.8311 - val_loss: 1.0007 - learning_rate: 0.0010
# Epoch 25/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8396 - loss: 0.9650 - val_accuracy: 0.8108 - val_loss: 0.9953 - learning_rate: 0.0010
# Epoch 26/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8681 - loss: 0.9388 - val_accuracy: 0.8243 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 27/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8311 - loss: 0.9586 - val_accuracy: 0.8176 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 28/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8330 - loss: 0.9837 - val_accuracy: 0.8311 - val_loss: 0.9819 - learning_rate: 0.0010
# Epoch 29/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8338 - loss: 0.9548 - val_accuracy: 0.8108 - val_loss: 0.9736 - learning_rate: 0.0010
# Epoch 30/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8807 - loss: 0.8815 - val_accuracy: 0.8378 - val_loss: 0.9772 - learning_rate: 0.0010
# Epoch 31/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8582 - loss: 0.9254 - val_accuracy: 0.8243 - val_loss: 0.9637 - learning_rate: 0.0010
# Epoch 32/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8316 - loss: 0.9525 - val_accuracy: 0.8243 - val_loss: 0.9566 - learning_rate: 0.0010
# Epoch 33/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8549 - loss: 0.8967 - val_accuracy: 0.8514 - val_loss: 0.9433 - learning_rate: 0.0010
# Epoch 34/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8386 - loss: 0.9067 - val_accuracy: 0.8514 - val_loss: 0.9323 - learning_rate: 0.0010
# Epoch 35/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8812 - loss: 0.8690 - val_accuracy: 0.8378 - val_loss: 0.9187 - learning_rate: 0.0010
# Epoch 36/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8454 - loss: 0.9035 - val_accuracy: 0.8581 - val_loss: 0.9144 - learning_rate: 0.0010
# Epoch 37/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8121 - loss: 0.9061 - val_accuracy: 0.8446 - val_loss: 0.9262 - learning_rate: 0.0010
# Epoch 38/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8948 - loss: 0.8157 - val_accuracy: 0.8716 - val_loss: 0.9420 - learning_rate: 0.0010
# Epoch 39/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8830 - loss: 0.8240 - val_accuracy: 0.8514 - val_loss: 0.9345 - learning_rate: 0.0010
# Epoch 40/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8322 - loss: 0.8692 - val_accuracy: 0.8243 - val_loss: 0.9534 - learning_rate: 0.0010
# Epoch 41/52
# 16/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8594 - loss: 0.8462
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8563 - loss: 0.8509 - val_accuracy: 0.8243 - val_loss: 0.9367 - learning_rate: 0.0010
# Epoch 42/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8501 - loss: 0.8344 - val_accuracy: 0.8311 - val_loss: 0.9299 - learning_rate: 5.0000e-04
# Epoch 43/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8899 - loss: 0.8120 - val_accuracy: 0.8378 - val_loss: 0.9309 - learning_rate: 5.0000e-04
# Epoch 44/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8981 - loss: 0.8056 - val_accuracy: 0.8446 - val_loss: 0.9379 - learning_rate: 5.0000e-04
# Epoch 45/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8737 - loss: 0.8314 - val_accuracy: 0.8514 - val_loss: 0.9310 - learning_rate: 5.0000e-04
# Epoch 46/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8840 - loss: 0.7974
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8835 - loss: 0.7984 - val_accuracy: 0.8446 - val_loss: 0.9365 - learning_rate: 5.0000e-04
# Epoch 47/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8606 - loss: 0.8167 - val_accuracy: 0.8378 - val_loss: 0.9421 - learning_rate: 2.5000e-04
# Epoch 48/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8718 - loss: 0.7925 - val_accuracy: 0.8514 - val_loss: 0.9364 - learning_rate: 2.5000e-04
# Epoch 49/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9032 - loss: 0.7497 - val_accuracy: 0.8378 - val_loss: 0.9344 - learning_rate: 2.5000e-04
# Epoch 50/52
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8819 - loss: 0.7595 - val_accuracy: 0.8514 - val_loss: 0.9332 - learning_rate: 2.5000e-04
# Epoch 51/52
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8867 - loss: 0.7670
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8865 - loss: 0.7683 - val_accuracy: 0.8378 - val_loss: 0.9324 - learning_rate: 2.5000e-04

# %%
# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8249 - loss: 0.9841
# Test Accuracy: 0.8315

# %%
y_pred = model.predict(x_test)
y_pred_labels = (y_pred > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred_labels))
print(classification_report(y_test, y_pred_labels))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy: 0.8315217391304348
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81        82
#            1       0.83      0.87      0.85       102
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.83      0.83       184
# weighted avg       0.83      0.83      0.83       184

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history.get('accuracy', history.history.get('acc'))  # Some versions use 'acc'
val_accuracy = history.history.get('val_accuracy', history.history.get('val_acc'))

epochs = range(1, len(loss) + 1)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'r*-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss Over Epochs')
plt.legend()

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r*-', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
import os
import time
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
from tensorflow.python.profiler import model_analyzer
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def evaluate_model_metrics(model, x_test, y_test, model_name="model_metrics"):
    results = {}

    # Total Parameters
    results['total_parameters'] = model.count_params()

    # FLOPs Calculation
    func = tf.function(lambda x: model(x))
    concrete_func = func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.inputs[0].dtype)
    )
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    flops = model_analyzer.profile(
        graph=frozen_func.graph,
        options=ProfileOptionBuilder.float_operation()
    ).total_float_ops
    results['FLOPs'] = flops
    results['GFLOPs'] = flops / 1e9

    # Model Size
    model_path = f"{model_name}.h5"
    model.save(model_path)
    size_bytes = os.path.getsize(model_path)
    results['model_size_bytes'] = size_bytes
    results['model_size_MB'] = size_bytes / (1024 * 1024)

    # Inference Time
    start = time.time()
    model.predict(x_test)
    end = time.time()
    results['inference_time_seconds'] = end - start

    # Accuracy
    loss, acc = model.evaluate(x_test, y_test, verbose=0)
    results['accuracy'] = acc

    return results

evaluate_model_metrics(model, x_test, y_test, model_name="model_metrics")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# {'total_parameters': 186305,
#  'FLOPs': 371601,
#  'GFLOPs': 0.000371601,
#  'model_size_bytes': 2341232,
#  'model_size_MB': 2.2327728271484375,
#  'inference_time_seconds': 0.4099867343902588,
#  'accuracy': 0.83152174949646}
